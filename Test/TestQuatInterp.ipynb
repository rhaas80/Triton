# %%
import PyGW.plot_on_spherevartheta, varphi = PyGW.plot_on_sphere.sphere_coordinates()x,y,z = PyGW.plot_on_sphere.sphere_points(vartheta, varphi)TestQuatInterpDat = genfromtxt('TestQuatInterp.dat')fig = figure()ax = fig.add_subplot(111, projection='3d')Surface = ax.plot_surface(0.95*x, 0.95*y, 0.95*z,                          rstride=10, cstride=10, linewidth=0.5, antialiased=False)Dots = ax.plot(TestQuatInterpDat[:,1], TestQuatInterpDat[:,2], TestQuatInterpDat[:,3], 'ro')

# %% [markdown]
# The above should show a sphere with various red dots, which depict the history of the $z$ axis as they are rotated by the various quaternions output by the `TestQuatInterp` routine.The basic upshot is that the curve should look pretty smooth, and should go through the locations corresponding to the `qIn` variable in `TestQuatInterp.cpp`.
