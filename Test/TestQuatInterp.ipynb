# %%
import PyGW.plot_on_sphereimport numpy as npyimport matplotlib.pyplot as pltvartheta, varphi = PyGW.plot_on_sphere.sphere_coordinates()x,y,z = PyGW.plot_on_sphere.sphere_points(vartheta, varphi)QuatInterpDat = npy.genfromtxt('TestQuatInterp.dat')fig = plt.figure()ax = fig.add_subplot(111, projection='3d')Surface = ax.plot_surface(0.95*x, 0.95*y, 0.95*z,                          rstride=10, cstride=10, linewidth=0.5, antialiased=False)Dots1 = ax.plot(QuatInterpDat[:5,1], QuatInterpDat[:5,2], QuatInterpDat[:5,3], 'go', ms=10)Dots2 = ax.plot(QuatInterpDat[5:,1], QuatInterpDat[5:,2], QuatInterpDat[5:,3], 'ro')

# %% [markdown]
# The above should show a sphere with various red dots, which depict the history of the $z$ axis as they are rotated by the various quaternions output by the `TestQuatInterp` routine.The basic upshot is that the curve should look pretty smooth, and should go through the locations corresponding to the `qIn` variable in `TestQuatInterp.cpp`, which should correspond to the green dots.

# %%
fig2 = plt.figure()ax2 = fig2.add_subplot(111)Xs2 = plt.plot(QuatInterpDat[5:,0],QuatInterpDat[5:,1], 'o')Ys2 = plt.plot(QuatInterpDat[5:,0],QuatInterpDat[5:,2], 'o')Zs2 = plt.plot(QuatInterpDat[5:,0],QuatInterpDat[5:,3], 'o')fig3 = plt.figure()ax3 = fig3.add_subplot(111)Xs3 = plt.plot(QuatInterpDat[6:,0],diff(QuatInterpDat[5:,1])/diff(QuatInterpDat[5:,0]), 'o')Ys3 = plt.plot(QuatInterpDat[6:,0],diff(QuatInterpDat[5:,2])/diff(QuatInterpDat[5:,0]), 'o')Zs3 = plt.plot(QuatInterpDat[6:,0],diff(QuatInterpDat[5:,3])/diff(QuatInterpDat[5:,0]), 'o')
